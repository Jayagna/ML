# %% [markdown]
# ![image_2024-08-05_140153334.png](data:image/png;base64,...)

# %% [markdown]
# **Classification Tree :**
#
# A classification tree is a type of decision tree algorithm used for predicting a categorical target variable. It is part of the supervised learning family of algorithms and is particularly useful for classification tasks.
#
# **Regression Tree :**
#
# A regression tree is similar to a classification tree, but it is used for predicting a continuous target variable. It is also a type of decision tree algorithm and is used for regression tasks.

# %% [markdown]
# # Decision Tree Regression

# %% [markdown]
# A decision tree is a versatile machine learning model that can be used for both classification and regression tasks. It splits the data based on feature values to make predictions and is valued for its simplicity and interpretability. However, it can suffer from overfitting and instability, which can be mitigated by techniques such as pruning, ensemble methods (e.g., Random Forests), and setting constraints on tree depth and minimum samples per leaf.

# %% [markdown]
# ![image_2024-08-05_142702259.png](data:image/png;base64,...)

# %% [markdown]
# The decision tree splits the graph in a number of sections each section called a terminal leaf.
#
# Suppose there is a new value added then its y value would be predicted by the decision tree as the average of all the points in the given terminal leaf.

# %% [markdown]
# ![image_2024-08-05_142914739.png](data:image/png;base64,...)

# %% [markdown]
# # NOTE
# Feature Scaling is not required in Decision Tree and Random Forest Regression.

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[: , 1:-1].values
y = dataset.iloc[: , -1].values

# %% [markdown]
# ## Training the Decision Tree Regression model on the whole dataset

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X , y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ## Predicting a new result

# %%
regressor.predict([[6.5]])
# Out:
# array([150000.])

# %% [markdown]
# ## Visualising the Decision Tree Regression results (higher resolution)

# %%
X_grid = np.arange(min(X) , max(X) , 0.1)
X_grid = X_grid.reshape(len(X_grid) , 1)
plt.scatter(X , y , color = 'red')
plt.plot(X_grid , regressor.predict(X_grid) , color = 'blue')
plt.title('Real or Bluff (Decision Tree)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()
# Out:
# <ipython-input-11-87d40668e459>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X) , max(X) , 0.1)
